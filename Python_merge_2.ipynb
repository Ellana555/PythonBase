# %% [markdown]
# <a href="https://colab.research.google.com/github/Ellana555/Skillfactory/blob/main/Python_merge_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Изучаем датасеты и загружаем
ratings = pd.read_csv('ratings.csv')

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movies = pd.read_csv('movies.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
# минимальное значение и сколько их
df = ratings[ratings['rating'] == 0.5]
print(df)
# Out:
#         userId  movieId  rating   timestamp
# 261          3       31     0.5  1306463578
# 262          3      527     0.5  1306464275
# 263          3      647     0.5  1306463619
# 264          3      688     0.5  1306464228
# 265          3      720     0.5  1306463595
# ...        ...      ...     ...         ...
# 99394      608     6827     0.5  1117519648
# 99408      608     7004     0.5  1117506252
# 100345     610    61818     0.5  1493848943
# 100415     610    72424     0.5  1493849030
# 100797     610   145951     0.5  1493849019
#
# [1370 rows x 4 columns]

# %%
max(ratings['rating'])
# Out:
# 5.0

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
joined = ratings.merge(movies, on='movieId', how='left')
joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
#  Проверка на дубликаты
len(ratings) == len(joined)
# Out:
# True

# %%
#Удаление дубликатов
movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 304.4+ KB

# %%
ratings.merge(movies, how = 'left', on = 'movieId')
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# ...

# %%
# данные о наличии товара на складе
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394],

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}

# %%
# данные о покупке товара
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132],

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}

# %%
# Переводим в ДФ
items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

# %%
itog_df = items_df.merge(purchase_df, on = 'item_id', how = 'left')
display(itog_df)
# Out:
#    item_id   vendor  stock_count  purchase_id    price
# 0   417283  Samsung           54        101.0  13900.0
# 1   849734       LG           33        101.0   5330.0
# 2   132223    Apple          122        101.0  38200.0
# 3   573943    Apple           18        112.0  49990.0
# 4    19475       LG          102        121.0   9890.0
# 5  3294095    Apple           43        145.0  33000.0
# 6   382043  Samsung           77        145.0  67500.0
# 7   302948  Samsung          143        145.0  34500.0
# 8   100132       LG           60        221.0  11400.0
# 9   312394      ZTE           19          NaN      NaN

# %%
# Добавляем объем
itog_df['volume'] = itog_df['stock_count'] * itog_df['price']

# %%
display(itog_df)
# Out:
#    item_id   vendor  stock_count  purchase_id    price     volume
# 0   417283  Samsung           54        101.0  13900.0   750600.0
# 1   849734       LG           33        101.0   5330.0   175890.0
# 2   132223    Apple          122        101.0  38200.0  4660400.0
# 3   573943    Apple           18        112.0  49990.0   899820.0
# 4    19475       LG          102        121.0   9890.0  1008780.0
# 5  3294095    Apple           43        145.0  33000.0  1419000.0
# 6   382043  Samsung           77        145.0  67500.0  5197500.0
# 7   302948  Samsung          143        145.0  34500.0  4933500.0
# 8   100132       LG           60        221.0  11400.0   684000.0
# 9   312394      ZTE           19          NaN      NaN        NaN

# %%
# выручка за весь объем
print(itog_df['volume'].sum())
# Out:
# 19729490.0

# %% [markdown]
# Выгрузка объединенной папки

# %%
import os

# %%
files = os.listdir('data')
files
# Out:
# ['ratings_7.txt',
#  'ratings_9.txt',
#  'ratings_6.txt',
#  'ratings_5.txt',
#  'ratings_4.txt',
#  'ratings_10.txt',
#  'ratings_8.txt',
#  'ratings_1.txt',
#  'ratings_3.txt',
#  'ratings_2.txt']

# %%
files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']

# %%
data = ['ratings.txt', 'stock_stats.txt', 'movies.txt']

# %%
#Создаем пустой датафрейм
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])

# %%
# Считываем файлы и склеиваем
for filename in files:
  temp = pd.read_csv( os.path.join('data', filename), names = ['userId', 'movieId', 'rating', 'timestamp'] )
  data = pd.concat([data, temp])

# %%
display(data)
# Out:
#      userId movieId  rating   timestamp
# 0       433    8636     4.0  1417930892
# 1       433    8641     4.5  1417930336
# 2       433    8665     3.0  1417929947
# 3       433    8961     4.5  1417929846
# 4       433   27773     5.0  1417930244
# ...     ...     ...     ...         ...
# 9995    133   65188     4.0  1416166822
# 9996    133   68157     5.0  1416147245
# 9997    133   69757     4.5  1416151741
# 9998    133   69844     4.0  1416151678
# 9999    133   71899     3.0  1416147749
#
# [100004 rows x 4 columns]

# %%
df = ratings.merge(movies, on = 'movieId', how = 'outer')
print(df.count())
# Out:
# userId       100836
# movieId      100854
# rating       100836
# timestamp    100836
# title        100854
# genres       100854
# dtype: int64

# %%
display(movies[movies['movieId'] == 3456])
# Out:
#       movieId                                         title genres
# 2587     3456  Color of Paradise, The (Rang-e khoda) (1999)  Drama
