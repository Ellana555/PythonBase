# %%
import numpy as np

# %%
# загадали число
number =  np.random.randint(1, 101)
print("Загаданное число =",number)
# Out:
# Загаданное число = 71

# %%
def game_core_v1(number):
    ''' Задача решалась методом пополам
     Сначала установили число 50 (середину диапазона),
     а после последовательно уменьшали или увеличивали число значение,
     в зависимости от того, больше оно или меньше нужного.
     Функция возвращает угаданное число в среднем за 6 попыток'''
    count = 1 # 1 попытка в случае совпадения предполагаемого числа с загаданным
    predict = 50
    # диапазон от 51 до 100
    if number > predict:
        predict += 25
        print(predict)
        count += 1
        if number > predict:
            predict += 12
            print(predict)
            count += 1
            if number > predict:
                predict += 7
                print(predict)
                count += 1
                
            else:
                predict -= 6
                print(predict)
                count += 1
        elif number < predict:
            predict -= 12
            print(predict)
            count += 1
            if number > predict:
                predict += 7
                print(predict)
                count += 1
            else:
                predict -= 6
                print(predict)
                count += 1

        # диапазон от 1 до 49
    else:
        predict -= 25
        print(predict)
        count += 1
        if number > predict:
            predict += 12
            print(predict)
            count += 1
            if number > predict:
                predict += 7
                print(predict)
                count += 1
            else:
                predict -= 6
                print(predict)
                count += 1
        elif number < predict:
            predict -= 12
            if number > predict:
                predict += 7
                print(predict)
                count += 1
            else:
                predict -= 6
                print(predict)
                count += 1
    # Циклы с предусловием для оставшихся значений
    while number != predict:
        count+=1
        print("Попытка = ",count - 1, "Предполагаемое число = ", predict, )
        if number > predict:
            predict += 1
        elif number < predict:
            predict -= 1
    return(count) # выход из цикла, если угадали

# %%
def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(1, 101, size=(1000))
    for number in random_array:
        count_ls.append(game_core(number))
        print(number)
    score = int(np.mean(count_ls))
    print(f"Алгоритм угадывает число в среднем за {score} попыток")
    return (score)

# %%
# запуск для проверки рабочей функции 
game_core_v1(number) 
# запуск проверки на скорость второй функции
score_game(game_core_v1)
# Out:
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# Попытка =  9 Предполагаемое число =  39
# 38
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# Попытка =  7 Предполагаемое число =  11
# Попытка =  8 Предполагаемое число =  12
# 13
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# Попытка =  6 Предполагаемое число =  72
# 73
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# 10
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# Попытка =  8 Предполагаемое число =  77
# 76
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 6
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 80
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# 65
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# 17
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# 2
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 25
# 7
# 7
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# Попытка =  9 Предполагаемое число =  52
# 51
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 21
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 19
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# Попытка =  7 Предполагаемое число =  11
# 12
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# 29
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# 30
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# 15
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# Попытка =  9 Предполагаемое число =  52
# 51
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 69
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 95
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# 97
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# Попытка =  8 Предполагаемое число =  85
# Попытка =  9 Предполагаемое число =  86
# 87
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# Попытка =  8 Предполагаемое число =  15
# 14
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# 10
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 8
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# Попытка =  9 Предполагаемое число =  65
# 64
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# Попытка =  8 Предполагаемое число =  61
# 62
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# 23
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 58
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# 2
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# Попытка =  8 Предполагаемое число =  2
# 1
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# 61
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 82
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# 9
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# 89
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# Попытка =  8 Предполагаемое число =  15
# 14
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# 48
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# Попытка =  6 Предполагаемое число =  72
# 73
# 25
# 37
# 31
# 31
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# 4
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 71
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# 22
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# Попытка =  9 Предполагаемое число =  49
# 50
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 58
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# 4
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 69
# 25
# 25
# 25
# 37
# 44
# 44
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# 27
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# 53
# 75
# 87
# 81
# 81
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# 42
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# 16
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# 65
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 69
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# 99
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 8
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# 27
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# 23
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# 10
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# 68
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# 28
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# Попытка =  9 Предполагаемое число =  39
# 38
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 58
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# 84
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# 39
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# 9
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# Попытка =  7 Предполагаемое число =  34
# 35
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# 11
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# 16
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 93
# 75
# 75
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# Попытка =  8 Предполагаемое число =  61
# Попытка =  9 Предполагаемое число =  62
# 63
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# 47
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# 89
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 56
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# 66
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# 4
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# Попытка =  8 Предполагаемое число =  2
# 1
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 25
# 7
# 7
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# 53
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# Попытка =  8 Предполагаемое число =  85
# 86
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 71
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# 3
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# 92
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# 22
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# Попытка =  8 Предполагаемое число =  77
# 76
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 8
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# Попытка =  6 Предполагаемое число =  72
# 73
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# Попытка =  8 Предполагаемое число =  77
# 76
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 25
# 37
# 44
# 44
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 21
# 25
# 37
# 31
# 31
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# Попытка =  7 Предполагаемое число =  34
# Попытка =  8 Предполагаемое число =  35
# Попытка =  9 Предполагаемое число =  36
# 37
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 8
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# 46
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 69
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 58
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# 97
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# Попытка =  8 Предполагаемое число =  15
# 14
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# 11
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 82
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 8
# 25
# 25
# 75
# 75
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 93
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 21
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# Попытка =  7 Предполагаемое число =  11
# Попытка =  8 Предполагаемое число =  12
# 13
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# 66
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 95
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# 61
# 25
# 25
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# 98
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# 3
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 93
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# 99
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# 11
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# 97
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# Попытка =  8 Предполагаемое число =  85
# Попытка =  9 Предполагаемое число =  86
# 87
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 71
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# 67
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# 49
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# 16
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 6
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# 18
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 43
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 21
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# 49
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# 23
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# Попытка =  8 Предполагаемое число =  15
# 14
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# 98
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# 54
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# 11
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# 97
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 56
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# Попытка =  8 Предполагаемое число =  61
# 62
# 75
# 63
# 57
# 57
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# 90
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# 22
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# 97
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# 84
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# 15
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# Попытка =  8 Предполагаемое число =  15
# 14
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 25
# 37
# 44
# 44
# 25
# 7
# 7
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 63
# 57
# 57
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# 60
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# 16
# 25
# 25
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# 10
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# 67
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# 54
# 75
# 63
# 70
# 70
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# Попытка =  7 Предполагаемое число =  34
# Попытка =  8 Предполагаемое число =  35
# Попытка =  9 Предполагаемое число =  36
# 37
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# 22
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# 41
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# 92
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# Попытка =  9 Предполагаемое число =  49
# 50
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# 48
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# 41
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# 79
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# 46
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# 17
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# 29
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# 46
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# 68
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# 67
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# 79
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# 47
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# Попытка =  8 Предполагаемое число =  2
# 1
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# 30
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# Попытка =  9 Предполагаемое число =  65
# 64
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# Попытка =  8 Предполагаемое число =  77
# 76
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# Попытка =  7 Предполагаемое число =  34
# Попытка =  8 Предполагаемое число =  35
# 36
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# 54
# 75
# 87
# 94
# 94
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# 34
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# 3
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# 84
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# 49
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# 29
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 56
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# 32
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# 29
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 95
# 75
# 75
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# 9
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# Попытка =  9 Предполагаемое число =  99
# 100
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# 9
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# Попытка =  9 Предполагаемое число =  52
# 51
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 80
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# 42
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# 65
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# 84
# 25
# 25
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 21
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 45
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# 16
# 25
# 37
# 31
# 31
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# 92
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# 15
# 25
# 20
# 20
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# 27
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# Попытка =  8 Предполагаемое число =  85
# Попытка =  9 Предполагаемое число =  86
# 87
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 8
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# Попытка =  9 Предполагаемое число =  99
# 100
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# 54
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# 48
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# 61
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# Попытка =  7 Предполагаемое число =  34
# 35
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 20
# 20
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# 68
# 25
# 25
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# 84
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 95
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# 39
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# 48
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 6
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 80
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# Попытка =  9 Предполагаемое число =  65
# 64
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 43
# 75
# 75
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# 67
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# 89
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# 99
# 25
# 37
# 31
# 31
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# 18
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 69
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# 65
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# 61
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# 79
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# 18
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# 40
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# Попытка =  7 Предполагаемое число =  34
# Попытка =  8 Предполагаемое число =  35
# 36
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 82
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# 29
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# 23
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# 39
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# 42
# 75
# 75
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 71
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# 49
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# Попытка =  9 Предполагаемое число =  52
# 51
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# Попытка =  8 Предполагаемое число =  61
# Попытка =  9 Предполагаемое число =  62
# 63
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 45
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# Попытка =  8 Предполагаемое число =  2
# 1
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# Попытка =  8 Предполагаемое число =  85
# Попытка =  9 Предполагаемое число =  86
# 87
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# 17
# 25
# 20
# 20
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# 10
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 93
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# 52
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# 11
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 69
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# 15
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# Попытка =  9 Предполагаемое число =  65
# 64
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# 22
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# 47
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# 4
# 75
# 63
# 57
# 57
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# 89
# 75
# 87
# 81
# 81
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# 47
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 80
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# 15
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# 16
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# 54
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# 59
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# Попытка =  8 Предполагаемое число =  85
# 86
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# 30
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 45
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# Попытка =  9 Предполагаемое число =  39
# 38
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# 23
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# 92
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# Попытка =  7 Предполагаемое число =  11
# Попытка =  8 Предполагаемое число =  12
# 13
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# 60
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# 27
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# 40
# 25
# 37
# 44
# 44
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# 39
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# 92
# 75
# 63
# 70
# 70
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# 99
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# 34
# 25
# 37
# 44
# 44
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# 27
# 75
# 63
# 57
# 57
# 75
# 63
# 70
# 70
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# Попытка =  6 Предполагаемое число =  72
# Попытка =  7 Предполагаемое число =  73
# 74
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# 53
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# 90
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# 28
# 25
# 37
# 44
# 44
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# 2
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 95
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# 97
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# 27
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 25
# 37
# 31
# 31
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# 65
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# 23
# 75
# 87
# 94
# ...
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# 39
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# Попытка =  7 Предполагаемое число =  11
# Попытка =  8 Предполагаемое число =  12
# 13
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 19
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# 89
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# 91
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# 84
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# 40
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# 99
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# 16
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# Попытка =  8 Предполагаемое число =  40
# Попытка =  9 Предполагаемое число =  39
# 38
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# 97
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# Попытка =  7 Предполагаемое число =  34
# Попытка =  8 Предполагаемое число =  35
# Попытка =  9 Предполагаемое число =  36
# 37
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# 99
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# 2
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 37
# 31
# 31
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 8
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# Попытка =  9 Предполагаемое число =  52
# 51
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# Попытка =  9 Предполагаемое число =  52
# 51
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# 33
# 25
# 37
# 44
# 44
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# 42
# 75
# 63
# 70
# 70
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# 2
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# 98
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# 52
# 25
# 37
# 31
# 31
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# Попытка =  9 Предполагаемое число =  49
# 50
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# 82
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# 96
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# 22
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 19
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# 47
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 45
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# 92
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# 10
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# 5
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# Попытка =  9 Предполагаемое число =  65
# 64
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# 96
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# 60
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# Попытка =  8 Предполагаемое число =  66
# 65
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# 32
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# 2
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# 85
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# 79
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# 69
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# Попытка =  7 Предполагаемое число =  28
# Попытка =  8 Предполагаемое число =  27
# 26
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# 84
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  30
# Попытка =  6 Предполагаемое число =  29
# 28
# 75
# 63
# 57
# 57
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# 93
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# 9
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 56
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# 77
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# 47
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# Попытка =  9 Предполагаемое число =  49
# 50
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# Попытка =  5 Предполагаемое число =  9
# Попытка =  6 Предполагаемое число =  10
# Попытка =  7 Предполагаемое число =  11
# 12
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  8
# 9
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# Попытка =  8 Предполагаемое число =  61
# 62
# 75
# 75
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# 89
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# 90
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# 83
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# 6
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 43
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# 47
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# 22
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# 52
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# Попытка =  6 Предполагаемое число =  72
# Попытка =  7 Предполагаемое число =  73
# 74
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 43
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# Попытка =  8 Предполагаемое число =  15
# 14
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# 19
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# Попытка =  6 Предполагаемое число =  23
# 24
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# 46
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# 96
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# 53
# 25
# 37
# 31
# Попытка =  4 Предполагаемое число =  31
# Попытка =  5 Предполагаемое число =  32
# Попытка =  6 Предполагаемое число =  33
# 34
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# 55
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  19
# Попытка =  5 Предполагаемое число =  18
# Попытка =  6 Предполагаемое число =  17
# Попытка =  7 Предполагаемое число =  16
# 15
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 58
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# Попытка =  8 Предполагаемое число =  61
# 62
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# 41
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# Попытка =  6 Предполагаемое число =  72
# 73
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  69
# Попытка =  6 Предполагаемое число =  68
# Попытка =  7 Предполагаемое число =  67
# 66
# 25
# 20
# Попытка =  3 Предполагаемое число =  20
# Попытка =  4 Предполагаемое число =  21
# Попытка =  5 Предполагаемое число =  22
# 23
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# 3
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  82
# Попытка =  6 Предполагаемое число =  83
# Попытка =  7 Предполагаемое число =  84
# Попытка =  8 Предполагаемое число =  85
# Попытка =  9 Предполагаемое число =  86
# 87
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# 2
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# Попытка =  6 Предполагаемое число =  72
# 73
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# Попытка =  7 Предполагаемое число =  54
# Попытка =  8 Предполагаемое число =  53
# 52
# 75
# 63
# 70
# Попытка =  4 Предполагаемое число =  70
# Попытка =  5 Предполагаемое число =  71
# 72
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  93
# Попытка =  6 Предполагаемое число =  92
# Попытка =  7 Предполагаемое число =  91
# Попытка =  8 Предполагаемое число =  90
# Попытка =  9 Предполагаемое число =  89
# 88
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# 78
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  58
# Попытка =  6 Предполагаемое число =  59
# Попытка =  7 Предполагаемое число =  60
# Попытка =  8 Предполагаемое число =  61
# Попытка =  9 Предполагаемое число =  62
# 63
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  45
# Попытка =  6 Предполагаемое число =  46
# Попытка =  7 Предполагаемое число =  47
# Попытка =  8 Предполагаемое число =  48
# 49
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# Попытка =  6 Предполагаемое число =  4
# Попытка =  7 Предполагаемое число =  3
# Попытка =  8 Предполагаемое число =  2
# 1
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# 43
# 25
# 37
# 44
# Попытка =  4 Предполагаемое число =  44
# Попытка =  5 Предполагаемое число =  43
# Попытка =  6 Предполагаемое число =  42
# Попытка =  7 Предполагаемое число =  41
# 40
# 25
# 7
# Попытка =  3 Предполагаемое число =  7
# Попытка =  4 Предполагаемое число =  6
# Попытка =  5 Предполагаемое число =  5
# 4
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# 58
# 25
# 37
# 44
# 44
# 75
# 63
# 57
# Попытка =  4 Предполагаемое число =  57
# Попытка =  5 Предполагаемое число =  56
# Попытка =  6 Предполагаемое число =  55
# 54
# 25
# 37
# 44
# 44
# 75
# 75
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# Попытка =  8 Предполагаемое число =  98
# 99
# 75
# 87
# 94
# Попытка =  4 Предполагаемое число =  94
# Попытка =  5 Предполагаемое число =  95
# Попытка =  6 Предполагаемое число =  96
# Попытка =  7 Предполагаемое число =  97
# 98
# 75
# 87
# 81
# Попытка =  4 Предполагаемое число =  81
# Попытка =  5 Предполагаемое число =  80
# Попытка =  6 Предполагаемое число =  79
# Попытка =  7 Предполагаемое число =  78
# Попытка =  8 Предполагаемое число =  77
# 76
# Алгоритм угадывает число в среднем за 6 попыток
# 6
