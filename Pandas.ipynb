# %% [markdown]
# <a href="https://colab.research.google.com/github/Ellana555/Skillfactory/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
print(pd.__name__)
# Out:
# pandas

# %% [markdown]
# # Series

# %%
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
print(countries.loc['US'])
# США
# Out:
# США

# %%
print(countries.loc[['US', 'RU', 'UK']])
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
print(countries.iloc[6])
# Казахстан
# Out:
# Казахстан

# %%
print(countries.iloc[1:4])
# Out:
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object

# %%
names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]

# %%
#Напишите функцию create_medications(names, counts), 
#создающую Series medications, индексами которого 
#являются названия лекарств names, а значениями — их количество в партии counts.

#Также напишите функцию get_percent(medications, name), 
#которая возвращает долю товара с именем name от общего 
#количества товаров в партии в процентах.

import pandas as pd
import numpy as np

def create_medications(names, counts):
    medications = pd.Series(
        data = counts,
        index = [names],
        name = 'medications')
    global sum_med
    sum_med = np.sum(counts)
    return medications

def get_percent(medications, name):
    count_name = medications.loc[name]
    procent = count_name / (sum_med / 100)
    return procent


if __name__ == '__main__':
    names=['chlorhexidine', 'cyntomycin', 'afobazol']
    counts=[15, 18, 7]
    medications = create_medications(names, counts)
    print(get_percent(medications, "chlorhexidine")) #37.5

names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]
# Out:
# chlorhexidine    37.5
# Name: medications, dtype: float64

# %% [markdown]
# # DataFrime

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
countries_df.mean(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# population    9.070000e+01
# square        5.800860e+06
# dtype: float64

# %%
countries_df.mean(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# UK      66726.145
# CA    4992354.025
# US    4913476.140
# RU    8562668.620
# UA     301836.750
# BY     103804.750
# KZ    1362459.520
# dtype: float64

# %%
countries_df.population
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
countries_df['population']
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
countries_df.loc['UK', 'square']
# Out:
# 133396

# %%
countries_df.loc['RU', ['population', 'square']]
# Out:
# population      146.24
# square        17125191
# Name: RU, dtype: object

# %%
pd.DataFrame([[0,1], [1, 0]], columns=['А', 'B'])
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
pd.DataFrame({'А': [0, 1], 'B': [1, 0]})
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
def create_companyDF(income, expenses, years):
    df = pd.DataFrame({
        'Income':income,
        'Expenses':expenses})
    df.index = years
    return df

# %%
income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]
display(create_companyDF(income, expenses, years))
# Out:
#       Income  Expenses
# 2018     478       156
# 2019     512       130
# 2020     196       270

# %%
import pandas as pd

def create_companyDF(income, expenses, years):
    df = pd.DataFrame({
        'Income':income,
        'Expenses':expenses},
        index = years)
    return df

def get_profit(df, year):
    if year in df.index:
        profit = df.loc[year, 'Income'] - df.loc[year, 'Expenses']
    else:
        profit=None
    return profit
    #df['pribil'] = df['income'] - df['expenses']
    #profit = pd.loc('year', 'pribil')
    
    """
    А также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанных в таблице df, за год year.
    Учтите, что если информация за запрашиваемый год не указана в вашей таблице вам необходимо вернуть None. 
    """
    #ваш код здесь
    return profit

if __name__ == '__main__':
    expenses = [156, 130, 270]
    income = [478, 512, 196]
    years = [2018, 2019, 2020]
    
    scienceyou = create_companyDF(income, expenses, years)
    print(get_profit(scienceyou, 2020)) #-74
# Out:
# -74

# %% [markdown]
# Работа с csv файлом

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 0          S      Biggin   3/12/2016       2.5  ...       1.0  1.0     202.0
# 1          S      Biggin   4/02/2016       2.5  ...       1.0  0.0     156.0
# 2         SP      Biggin   4/03/2017       2.5  ...       2.0  0.0     134.0
# 3         PI      Biggin   4/03/2017       2.5  ...       2.0  1.0      94.0
# 4         VB      Nelson   4/06/2016       2.5  ...       1.0  2.0     120.0
# ...      ...         ...         ...       ...  ...       ...  ...       ...
# 18391     SP        Greg  26/08/2017       6.8  ...       2.0  1.0       NaN
# 18392     PI     Sweeney  26/08/2017       6.8  ...       1.0  5.0     866.0
# 18393      S  Buckingham  26/08/2017      12.7  ...       3.0  2.0       NaN
# 18394     SP     Village  26/08/2017       6.3  ...       1.0  1.0     362.0
# 18395     VB     Village  26/08/2017       6.3  ...       2.0  2.0       NaN
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# 0               NaN        NaN        Yarra  -37.79960  144.99840
# 1              79.0     1900.0        Yarra  -37.80790  144.99340
# 2             150.0     1900.0        Yarra  -37.80930  144.99440
# 3               NaN        NaN        Yarra  -37.79690  144.99690
# 4             142.0     2014.0        Yarra  -37.80720  144.99410
# ...             ...        ...          ...        ...        ...
# 18391          89.0     2010.0          NaN  -37.86393  144.90484
# 18392         157.0     1920.0          NaN  -37.85908  144.89299
# 18393           NaN        NaN          NaN  -37.72006  145.10547
# 18394         112.0     1920.0          NaN  -37.81188  144.88449
# 18395         139.0     1950.0          NaN  -37.81829  144.87404
#
#                   Regionname  Propertycount
# 0      Northern Metropolitan         4019.0
# 1      Northern Metropolitan         4019.0
# 2      Northern Metropolitan         4019.0
# 3      Northern Metropolitan         4019.0
# 4      Northern Metropolitan         4019.0
# ...                      ...            ...
# 18391   Western Metropolitan         6380.0
# 18392   Western Metropolitan         6380.0
# 18393  Northern Metropolitan         1369.0
# 18394   Western Metropolitan         6543.0
# 18395   Western Metropolitan         6543.0
#
# [18396 rows x 22 columns]

# %%
melb_data = pd.read_csv('/content/data/melb_data.csv', sep=',')

# %%
display(melb_data)
# Out:
#        index          Suburb           Address  Rooms Type      Price Method  \
# 0          0      Abbotsford      85 Turner St    2.0    h  1480000.0      S
# 1          1      Abbotsford   25 Bloomburg St    2.0    h  1035000.0      S
# 2          2      Abbotsford      5 Charles St    3.0    h  1465000.0     SP
# 3          3      Abbotsford  40 Federation La    3.0    h   850000.0     PI
# 4          4      Abbotsford       55a Park St    4.0    h  1600000.0     VB
# ...      ...             ...               ...    ...  ...        ...    ...
# 19184  11336  Doncaster East    26 Champion St    3.0    h  1735000.0      S
# 19185  11337         Donvale    6/22 Powers St    3.0    t   920000.0      S
# 19186  11338         Donvale     14 Sturdee Rd    3.0    h   904000.0      S
# 19187  11339         Doveton      5 Crimson Dr    3.0    h   500000.0      S
# 19188  11340       Eaglemont    104 Studley Rd    3.0    h  1440000.0      S
#
#          SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 0         Biggin   3/12/2016       2.5  ...  1.0     202.0         126.0
# 1         Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0
# 2         Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0
# 3         Biggin   4/03/2017       2.5  ...  1.0      94.0         126.0
# 4         Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0
# ...          ...         ...       ...  ...  ...       ...           ...
# 19184     Jellis  15/07/2017      14.3  ...  2.0     725.0         126.0
# 19185      Barry  15/07/2017      16.1  ...  2.0     239.0         187.0
# 19186  Fletchers  15/07/2017      16.1  ...  2.0     720.0         116.0
# 19187       Hall  15/07/2017      28.8  ...  3.0     621.0         126.0
# 19188      Miles           1       NaN  ...  NaN       NaN           NaN
#
#        YearBuilt  CouncilArea            Lattitude  Longtitude  \
# 0         1970.0        Yarra             -37.7996   144.99840
# 1         1900.0        Yarra             -37.8079   144.99340
# 2         1900.0        Yarra             -37.8093   144.99440
# 3         1970.0        Yarra             -37.7969   144.99690
# 4         2014.0        Yarra             -37.8072   144.99410
# ...          ...          ...                  ...         ...
# 19184     1970.0   Manningham            -37.78707   145.15161
# 19185     2007.0   Manningham            -37.77323   145.18029
# 19186     1960.0   Manningham  -37.803490000000004   145.19666
# 19187     1955.0        Casey            -37.98537   145.23505
# 19188        NaN          NaN                  NaN         NaN
#
#                        Regionname Propertycount           Coordinates
# 0           Northern Metropolitan        4019.0    -37.7996, 144.9984
# 1           Northern Metropolitan        4019.0    -37.8079, 144.9934
# 2           Northern Metropolitan        4019.0    -37.8093, 144.9944
# 3           Northern Metropolitan        4019.0    -37.7969, 144.9969
# 4           Northern Metropolitan        4019.0    -37.8072, 144.9941
# ...                           ...           ...                   ...
# 19184        Eastern Metropolitan       10999.0  -37.78707, 145.15161
# 19185        Eastern Metropolitan        4790.0  -37.77323, 145.18029
# 19186        Eastern Metropolitan        4790.0  -37.80349, 145.19666
# 19187  South-Eastern Metropolitan        3533.0  -37.98537, 145.23505
# 19188                         NaN           NaN                   NaN
#
# [19189 rows x 23 columns]

# %%
display(melb_data.head())
# Out:
#   index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0     0  Abbotsford      85 Turner St    2.0    h  1480000.0      S  Biggin
# 1     1  Abbotsford   25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 2     2  Abbotsford      5 Charles St    3.0    h  1465000.0     SP  Biggin
# 3     3  Abbotsford  40 Federation La    3.0    h   850000.0     PI  Biggin
# 4     4  Abbotsford       55a Park St    4.0    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea Lattitude  Longtitude             Regionname Propertycount  \
# 0        Yarra  -37.7996    144.9984  Northern Metropolitan        4019.0
# 1        Yarra  -37.8079    144.9934  Northern Metropolitan        4019.0
# 2        Yarra  -37.8093    144.9944  Northern Metropolitan        4019.0
# 3        Yarra  -37.7969    144.9969  Northern Metropolitan        4019.0
# 4        Yarra  -37.8072    144.9941  Northern Metropolitan        4019.0
#
#           Coordinates
# 0  -37.7996, 144.9984
# 1  -37.8079, 144.9934
# 2  -37.8093, 144.9944
# 3  -37.7969, 144.9969
# 4  -37.8072, 144.9941
#
# [5 rows x 23 columns]

# %%
melb_data.tail(7)
# Out:
#        index           Suburb         Address  Rooms Type      Price Method  \
# 19182  11334  Dingley Village   29 Elliott Cr    3.0    h   800000.0      S
# 19183  11335  Dingley Village    5 Tarnook Ct    4.0    h   854000.0      S
# 19184  11336   Doncaster East  26 Champion St    3.0    h  1735000.0      S
# 19185  11337          Donvale  6/22 Powers St    3.0    t   920000.0      S
# 19186  11338          Donvale   14 Sturdee Rd    3.0    h   904000.0      S
# 19187  11339          Doveton    5 Crimson Dr    3.0    h   500000.0      S
# 19188  11340        Eaglemont  104 Studley Rd    3.0    h  1440000.0      S
#
#          SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 19182        Ray  15/07/2017      22.2  ...  4.0     801.0         150.0
# 19183        Ray  15/07/2017      22.2  ...  2.0     676.0         181.0
# 19184     Jellis  15/07/2017      14.3  ...  2.0     725.0         126.0
# 19185      Barry  15/07/2017      16.1  ...  2.0     239.0         187.0
# 19186  Fletchers  15/07/2017      16.1  ...  2.0     720.0         116.0
# 19187       Hall  15/07/2017      28.8  ...  3.0     621.0         126.0
# 19188      Miles           1       NaN  ...  NaN       NaN           NaN
#
#        YearBuilt  CouncilArea            Lattitude  Longtitude  \
# 19182     1980.0     Kingston            -37.98596   145.13187
# 19183     1975.0     Kingston            -37.97936   145.13302
# 19184     1970.0   Manningham            -37.78707   145.15161
# 19185     2007.0   Manningham            -37.77323   145.18029
# 19186     1960.0   Manningham  -37.803490000000004   145.19666
# 19187     1955.0        Casey            -37.98537   145.23505
# 19188        NaN          NaN                  NaN         NaN
#
#                        Regionname Propertycount           Coordinates
# 19182  South-Eastern Metropolitan        3940.0  -37.98596, 145.13187
# 19183  South-Eastern Metropolitan        3940.0  -37.97936, 145.13302
# 19184        Eastern Metropolitan       10999.0  -37.78707, 145.15161
# 19185        Eastern Metropolitan        4790.0  -37.77323, 145.18029
# 19186        Eastern Metropolitan        4790.0  -37.80349, 145.19666
# 19187  South-Eastern Metropolitan        3533.0  -37.98537, 145.23505
# 19188                         NaN           NaN                   NaN
#
# [7 rows x 23 columns]

# %%
 melb_data.shape
# Out:
# (19189, 23)

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19189 entries, 0 to 19188
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          19189 non-null  object
#  1   Suburb         19189 non-null  object
#  2   Address        19189 non-null  object
#  3   Rooms          19189 non-null  float64
#  4   Type           19189 non-null  object
#  5   Price          19189 non-null  object
#  6   Method         19189 non-null  object
#  7   SellerG        19189 non-null  object
#  8   Date           19189 non-null  object
#  9   Distance       19188 non-null  float64
#  10  Postcode       19188 non-null  float64
#  11  Bedroom        19188 non-null  float64
#  12  Bathroom       19188 non-null  float64
#  13  Car            19188 non-null  float64
#  14  Landsize       19188 non-null  float64
#  15  BuildingArea   19188 non-null  object
#  16  YearBuilt      19188 non-null  float64
#  17  CouncilArea    17817 non-null  object
#  18  Lattitude      19188 non-null  object
#  19  Longtitude     19188 non-null  float64
#  20  Regionname     19188 non-null  object
#  21  Propertycount  19187 non-null  float64
#  22  Coordinates    19187 non-null  object
# dtypes: float64(10), object(13)
# memory usage: 3.4+ MB

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-76-1f62ef8091a4> in <module>()
# ----> 1 melb_data['Car'] = melb_data['Car'].astype('int64')
#       2 melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
#       3 melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
#       4 melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
#       5 melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1166
#    1167     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1168         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1169
#    1170     elif is_object_dtype(arr):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1212     if not np.isfinite(values).all():
#    1213         raise IntCastingNaNError(
# -> 1214             "Cannot convert non-finite values (NA or inf) to integer"
#    1215         )
#    1216     return values.astype(dtype, copy=copy)
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-975cb54141e6> in <module>()
# ----> 1 melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['BuildingArea', 'Price'] not in index"
