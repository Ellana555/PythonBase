# %% [markdown]
# <a href="https://colab.research.google.com/github/Ellana555/Skillfactory/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
print(pd.__name__)
# Out:
# pandas

# %% [markdown]
# # Series

# %%
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
countries = pd.Series({
    'UK': 'Англия',
    'CA': 'Канада',
    'US' : 'США',
    'RU': 'Россия',
    'UA': 'Украина',
    'BY': 'Беларусь',
    'KZ': 'Казахстан'},
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %%
print(countries.loc['US'])
# США
# Out:
# США

# %%
print(countries.loc[['US', 'RU', 'UK']])
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
print(countries.iloc[6])
# Казахстан
# Out:
# Казахстан

# %%
print(countries.iloc[1:4])
# Out:
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object

# %%
names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]

# %%
#Напишите функцию create_medications(names, counts), 
#создающую Series medications, индексами которого 
#являются названия лекарств names, а значениями — их количество в партии counts.

#Также напишите функцию get_percent(medications, name), 
#которая возвращает долю товара с именем name от общего 
#количества товаров в партии в процентах.

import pandas as pd
import numpy as np

def create_medications(names, counts):
    medications = pd.Series(
        data = counts,
        index = [names],
        name = 'medications')
    global sum_med
    sum_med = np.sum(counts)
    return medications

def get_percent(medications, name):
    count_name = medications.loc[name]
    procent = count_name / (sum_med / 100)
    return procent


if __name__ == '__main__':
    names=['chlorhexidine', 'cyntomycin', 'afobazol']
    counts=[15, 18, 7]
    medications = create_medications(names, counts)
    print(get_percent(medications, "chlorhexidine")) #37.5

names=['chlorhexidine', 'cyntomycin', 'afobazol']
counts=[15, 18, 7]
# Out:
# chlorhexidine    37.5
# Name: medications, dtype: float64

# %% [markdown]
# # DataFrime

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %%
countries_df.mean(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# population    9.070000e+01
# square        5.800860e+06
# dtype: float64

# %%
countries_df.mean(axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# UK      66726.145
# CA    4992354.025
# US    4913476.140
# RU    8562668.620
# UA     301836.750
# BY     103804.750
# KZ    1362459.520
# dtype: float64

# %%
countries_df.population
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
countries_df['population']
# Out:
# UK     56.29
# CA     38.05
# US    322.28
# RU    146.24
# UA     45.50
# BY      9.50
# KZ     17.04
# Name: population, dtype: float64

# %%
countries_df.loc['UK', 'square']
# Out:
# 133396

# %%
countries_df.loc['RU', ['population', 'square']]
# Out:
# population      146.24
# square        17125191
# Name: RU, dtype: object

# %%
pd.DataFrame([[0,1], [1, 0]], columns=['А', 'B'])
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
pd.DataFrame({'А': [0, 1], 'B': [1, 0]})
# Out:
#    А  B
# 0  0  1
# 1  1  0

# %%
def create_companyDF(income, expenses, years):
    df = pd.DataFrame({
        'Income':income,
        'Expenses':expenses})
    df.index = years
    return df

# %%
income = [478, 512, 196]
expenses = [156, 130, 270]
years = [2018, 2019, 2020]
display(create_companyDF(income, expenses, years))
# Out:
#       Income  Expenses
# 2018     478       156
# 2019     512       130
# 2020     196       270

# %%
import pandas as pd

def create_companyDF(income, expenses, years):
    df = pd.DataFrame({
        'Income':income,
        'Expenses':expenses},
        index = years)
    return df

def get_profit(df, year):
    if year in df.index:
        profit = df.loc[year, 'Income'] - df.loc[year, 'Expenses']
    else:
        profit=None
    return profit
    #df['pribil'] = df['income'] - df['expenses']
    #profit = pd.loc('year', 'pribil')
    
    """
    А также напишите функцию get_profit(df, year), которая возвращает разницу между доходом и расходом, записанных в таблице df, за год year.
    Учтите, что если информация за запрашиваемый год не указана в вашей таблице вам необходимо вернуть None. 
    """
    #ваш код здесь
    return profit

if __name__ == '__main__':
    expenses = [156, 130, 270]
    income = [478, 512, 196]
    years = [2018, 2019, 2020]
    
    scienceyou = create_companyDF(income, expenses, years)
    print(get_profit(scienceyou, 2020)) #-74
# Out:
# -74

# %% [markdown]
# Работа с csv файлом

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        index          Suburb           Address  Rooms Type      Price Method  \
# 0          0      Abbotsford      85 Turner St    2.0    h  1480000.0      S
# 1          1      Abbotsford   25 Bloomburg St    2.0    h  1035000.0      S
# 2          2      Abbotsford      5 Charles St    3.0    h  1465000.0     SP
# 3          3      Abbotsford  40 Federation La    3.0    h   850000.0     PI
# 4          4      Abbotsford       55a Park St    4.0    h  1600000.0     VB
# ...      ...             ...               ...    ...  ...        ...    ...
# 19184  11336  Doncaster East    26 Champion St    3.0    h  1735000.0      S
# 19185  11337         Donvale    6/22 Powers St    3.0    t   920000.0      S
# 19186  11338         Donvale     14 Sturdee Rd    3.0    h   904000.0      S
# 19187  11339         Doveton      5 Crimson Dr    3.0    h   500000.0      S
# 19188  11340       Eaglemont    104 Studley Rd    3.0    h  1440000.0      S
#
#          SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 0         Biggin   3/12/2016       2.5  ...  1.0     202.0         126.0
# 1         Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0
# 2         Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0
# 3         Biggin   4/03/2017       2.5  ...  1.0      94.0         126.0
# 4         Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0
# ...          ...         ...       ...  ...  ...       ...           ...
# 19184     Jellis  15/07/2017      14.3  ...  2.0     725.0         126.0
# 19185      Barry  15/07/2017      16.1  ...  2.0     239.0         187.0
# 19186  Fletchers  15/07/2017      16.1  ...  2.0     720.0         116.0
# 19187       Hall  15/07/2017      28.8  ...  3.0     621.0         126.0
# 19188      Miles           1       NaN  ...  NaN       NaN           NaN
#
#        YearBuilt  CouncilArea            Lattitude  Longtitude  \
# 0         1970.0        Yarra             -37.7996   144.99840
# 1         1900.0        Yarra             -37.8079   144.99340
# 2         1900.0        Yarra             -37.8093   144.99440
# 3         1970.0        Yarra             -37.7969   144.99690
# 4         2014.0        Yarra             -37.8072   144.99410
# ...          ...          ...                  ...         ...
# 19184     1970.0   Manningham            -37.78707   145.15161
# 19185     2007.0   Manningham            -37.77323   145.18029
# 19186     1960.0   Manningham  -37.803490000000004   145.19666
# 19187     1955.0        Casey            -37.98537   145.23505
# 19188        NaN          NaN                  NaN         NaN
#
#                        Regionname Propertycount           Coordinates
# 0           Northern Metropolitan        4019.0    -37.7996, 144.9984
# 1           Northern Metropolitan        4019.0    -37.8079, 144.9934
# 2           Northern Metropolitan        4019.0    -37.8093, 144.9944
# 3           Northern Metropolitan        4019.0    -37.7969, 144.9969
# 4           Northern Metropolitan        4019.0    -37.8072, 144.9941
# ...                           ...           ...                   ...
# 19184        Eastern Metropolitan       10999.0  -37.78707, 145.15161
# 19185        Eastern Metropolitan        4790.0  -37.77323, 145.18029
# 19186        Eastern Metropolitan        4790.0  -37.80349, 145.19666
# 19187  South-Eastern Metropolitan        3533.0  -37.98537, 145.23505
# 19188                         NaN           NaN                   NaN
#
# [19189 rows x 23 columns]
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.

# %%
melb_data = pd.read_csv('/content/data/melb_data.csv', sep=',')

# %%
display(melb_data)
# Out:
#        index          Suburb           Address  Rooms Type      Price Method  \
# 0          0      Abbotsford      85 Turner St    2.0    h  1480000.0      S
# 1          1      Abbotsford   25 Bloomburg St    2.0    h  1035000.0      S
# 2          2      Abbotsford      5 Charles St    3.0    h  1465000.0     SP
# 3          3      Abbotsford  40 Federation La    3.0    h   850000.0     PI
# 4          4      Abbotsford       55a Park St    4.0    h  1600000.0     VB
# ...      ...             ...               ...    ...  ...        ...    ...
# 19184  11336  Doncaster East    26 Champion St    3.0    h  1735000.0      S
# 19185  11337         Donvale    6/22 Powers St    3.0    t   920000.0      S
# 19186  11338         Donvale     14 Sturdee Rd    3.0    h   904000.0      S
# 19187  11339         Doveton      5 Crimson Dr    3.0    h   500000.0      S
# 19188  11340       Eaglemont    104 Studley Rd    3.0    h  1440000.0      S
#
#          SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  \
# 0         Biggin   3/12/2016       2.5  ...  1.0     202.0         126.0
# 1         Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0
# 2         Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0
# 3         Biggin   4/03/2017       2.5  ...  1.0      94.0         126.0
# 4         Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0
# ...          ...         ...       ...  ...  ...       ...           ...
# 19184     Jellis  15/07/2017      14.3  ...  2.0     725.0         126.0
# 19185      Barry  15/07/2017      16.1  ...  2.0     239.0         187.0
# 19186  Fletchers  15/07/2017      16.1  ...  2.0     720.0         116.0
# 19187       Hall  15/07/2017      28.8  ...  3.0     621.0         126.0
# 19188      Miles           1       NaN  ...  NaN       NaN           NaN
#
#        YearBuilt  CouncilArea            Lattitude  Longtitude  \
# 0         1970.0        Yarra             -37.7996   144.99840
# 1         1900.0        Yarra             -37.8079   144.99340
# 2         1900.0        Yarra             -37.8093   144.99440
# 3         1970.0        Yarra             -37.7969   144.99690
# 4         2014.0        Yarra             -37.8072   144.99410
# ...          ...          ...                  ...         ...
# 19184     1970.0   Manningham            -37.78707   145.15161
# 19185     2007.0   Manningham            -37.77323   145.18029
# 19186     1960.0   Manningham  -37.803490000000004   145.19666
# 19187     1955.0        Casey            -37.98537   145.23505
# 19188        NaN          NaN                  NaN         NaN
#
#                        Regionname Propertycount           Coordinates
# 0           Northern Metropolitan        4019.0    -37.7996, 144.9984
# 1           Northern Metropolitan        4019.0    -37.8079, 144.9934
# 2           Northern Metropolitan        4019.0    -37.8093, 144.9944
# 3           Northern Metropolitan        4019.0    -37.7969, 144.9969
# 4           Northern Metropolitan        4019.0    -37.8072, 144.9941
# ...                           ...           ...                   ...
# 19184        Eastern Metropolitan       10999.0  -37.78707, 145.15161
# 19185        Eastern Metropolitan        4790.0  -37.77323, 145.18029
# 19186        Eastern Metropolitan        4790.0  -37.80349, 145.19666
# 19187  South-Eastern Metropolitan        3533.0  -37.98537, 145.23505
# 19188                         NaN           NaN                   NaN
#
# [19189 rows x 23 columns]
# Warning: Total number of columns (23) exceeds max_columns (20) limiting to first (20) columns.
