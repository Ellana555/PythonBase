# %% [markdown]
# <a href="https://colab.research.google.com/github/Ellana555/Skillfactory/blob/main/Speki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import glob

# %%
import tabula

# %%
pdf_files = glob.glob('/content/speki_school/*.pdf')
pdf_files
# Out:
# ['/content/speki_school/RM16751_SBID7015_МО, г. Реутов, ул. Победы, 7 Аv1.pdf',
#  '/content/speki_school/16053_6338_МО,_п._Мостовик,_ул._Первомайская,_14_V2.pdf',
#  '/content/speki_school/RM16001_SBID6289_МО г. Реутов, ул. Гагарина, 17Бv2.pdf',
#  '/content/speki_school/RM15609_SBID5913_МО, г. Лобня, ул. Аэропортовская, 1v1.pdf',
#  '/content/speki_school/16534_6808__МО_г.о._Талдомский_г.о,_д._Кошелево,_д._65_v3_31.05.2022.pdf',
#  '/content/speki_school/RM15995_SBID6283_МО, г. Реутов, ул. Победы, 32v1.pdf',
#  '/content/speki_school/16921_16550_Московская область, Зарайск городской округ, деревня Журавна, 73 V3.pdf',
#  '/content/speki_school/16357 Зарайск городской округ, город Зарайск, улица Московская, 1(v3).pdf',
#  '/content/speki_school/15412_Московская область, Зарайск городской округ, деревня Мендюкино, 99_V3.pdf',
#  '/content/speki_school/16922 16551Зарайск городской округ, поселок Центральной усадьбы совхоза 40 лет Октября, улица Садовая, 15(v3).pdf',
# ...

# %%
df_single = pd.DataFrame()
for pdf_file in pdf_files:
    pdf_table = tabula.read_pdf(pdf_file,
                             pages='30-50',
                             multiple_tables=True,
                             lattice=True)
    for pdf_table in pdf_tables:
        col_count = len(table.columns)
        if (col_count >= 3 and col_count <= 11) and table.columns[0] == 'Unnamed: 0':
            df_single = pd.concat([df_single, table])
        else:
            continue
# Out:
# Got stderr: Jun 20, 2022 2:25:55 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Jun 20, 2022 2:25:55 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'ArialNarrow'
# Jun 20, 2022 2:25:56 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'Helvetica,Bold'
# Jun 20, 2022 2:25:57 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Jun 20, 2022 2:25:57 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'TimesNewRomanPS-BoldMT'
# Jun 20, 2022 2:25:58 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
#
# Error from tabula-java:
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df_single

# %%
pdf_tables = tabula.read_pdf(pdf_files[0],
                             pages='30-50',
                             multiple_tables=True,
                             lattice=True)
# Out:
# Got stderr: Jun 20, 2022 12:46:55 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Jun 20, 2022 12:46:55 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'ArialNarrow'
# Jun 20, 2022 12:46:56 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'Helvetica,Bold'
# Jun 20, 2022 12:46:57 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'
# Jun 20, 2022 12:46:57 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'TimesNewRomanPS-BoldMT'
# Jun 20, 2022 12:46:57 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'TimesNewRomanPSMT'

# %%
for  table in pdf_tables:
    display(table)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1]
# Index: []
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1]
# Index: []
#                                            Unnamed: 0 Unnamed: 1  \
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3                                                 NaN        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6                                                 NaN        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# ...

# %%
print(pdf_tables[0].columns[0])
# Out:
# Unnamed: 0

# %%
df_single = pd.DataFrame()

for table in pdf_tables:
    col_count = len(table.columns)
    if (col_count >= 3 and col_count <= 11) and table.columns[0] == 'Unnamed: 0':
        df_single = pd.concat([df_single, table])
    else:
      continue

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df_single
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
df_single.to_csv('RM16751_SBID7015_МО.csv')
